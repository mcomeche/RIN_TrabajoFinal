# %%
import paho.mqtt.client as mqtt
from pymongo import MongoClient
from datetime import datetime
import json
import signal
import sys
import logging

# Basic logging configuration
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.StreamHandler()
    ]
)

logger = logging.getLogger(__name__)

# Configuration
CONFIG = {
    "MQTT": {
        "BROKER_URL": "broker.hivemq.com",
        "PORT": 1883,
        "TOPIC": "RIN",  # Changed to match ESP32 topic
        "KEEPALIVE": 60
    },
    "MONGODB": {
        "URI": "mongodb://localhost:27017",
        "DB_NAME": "TrabajoRIN",
        "COLLECTION": "parking_events"  # Single collection for all events
    }
}

class MQTTToMongoDBService:
    def __init__(self):
        self.mongo_client = None
        self.db = None
        self.collection = None
        self.mqtt_client = None
        self.setup_signal_handlers()

    def setup_signal_handlers(self):
        signal.signal(signal.SIGINT, self.handle_shutdown)
        signal.signal(signal.SIGTERM, self.handle_shutdown)

    def handle_shutdown(self, signum, frame):
        logger.info("Received termination signal. Closing connections...")
        if self.mqtt_client:
            self.mqtt_client.disconnect()
        if self.mongo_client:
            self.mongo_client.close()
        logger.info("Connections closed. Exiting...")
        sys.exit(0)

    def store_event_data(self, data):
        try:
            # Create document with additional metadata
            doc = {
                "event_type": data.get("evento"),  # "entrada" or "salida"
                "event_time": data.get("hora"),   # Time from ESP32
                "total_cars": data.get("totalCoches"),
                "entry_distance": data.get("distanciaEntrada"),
                "exit_distance": data.get("distanciaSalida"),
                "received_at": datetime.now(),    # Server reception time
                "source": "ESP32_RIN"              # Identifier for data source
            }
            
            result = self.collection.insert_one(doc)
            logger.info(f"Event stored - Type: {doc['event_type']}, Cars: {doc['total_cars']}")
            return result.inserted_id
            
        except Exception as e:
            logger.error(f"Error storing event: {str(e)}")
            raise

    def on_mqtt_connect(self, client, userdata, flags, rc):
        if rc == 0:
            logger.info("Connected to MQTT broker")
            client.subscribe(CONFIG["MQTT"]["TOPIC"])
        else:
            logger.error(f"MQTT connection error. Code: {rc}")

    def on_mqtt_message(self, client, userdata, msg):
        try:
            # Parse the JSON message
            data = json.loads(msg.payload.decode())
            logger.info(f"Received message: {data}")
            
            # Store the event data in MongoDB
            self.store_event_data(data)

        except json.JSONDecodeError as e:
            logger.error(f"JSON decode error: {str(e)}")
        except Exception as e:
            logger.error(f"Unexpected error: {str(e)}")

    def on_mqtt_disconnect(self, client, userdata, rc):
        if rc != 0:
            logger.warning(f"Unexpected MQTT disconnection. Reconnecting... Code: {rc}")

    def connect_to_mongodb(self):
        try:
            self.mongo_client = MongoClient(CONFIG["MONGODB"]["URI"])
            self.db = self.mongo_client[CONFIG["MONGODB"]["DB_NAME"]]
            self.collection = self.db[CONFIG["MONGODB"]["COLLECTION"]]
            
            # Test the connection
            self.db.command("ping")
            logger.info("Connected to MongoDB")
            return True
            
        except Exception as e:
            logger.error(f"Error connecting to MongoDB: {str(e)}")
            return False

    def setup_mqtt_client(self):
        self.mqtt_client = mqtt.Client()
        self.mqtt_client.on_connect = self.on_mqtt_connect
        self.mqtt_client.on_message = self.on_mqtt_message
        self.mqtt_client.on_disconnect = self.on_mqtt_disconnect
        
        try:
            self.mqtt_client.connect(
                CONFIG["MQTT"]["BROKER_URL"],
                port=CONFIG["MQTT"]["PORT"],
                keepalive=CONFIG["MQTT"]["KEEPALIVE"]
            )
            return True
        except Exception as e:
            logger.error(f"Error connecting to MQTT: {str(e)}")
            return False

    def run(self):
        if not self.connect_to_mongodb():
            logger.error("Could not connect to MongoDB. Exiting...")
            sys.exit(1)
            
        if not self.setup_mqtt_client():
            logger.error("Could not connect to MQTT. Exiting...")
            sys.exit(1)
            
        logger.info("Service started. Waiting for messages...")
        self.mqtt_client.loop_forever()

if __name__ == "__main__":
    service = MQTTToMongoDBService()
    try:
        service.run()
    except KeyboardInterrupt:
        logger.info("Service stopped by user")
    except Exception as e:
        logger.error(f"Unexpected error: {str(e)}")
        sys.exit(1)
# Out:
# 2025-05-27 15:14:58,179 - INFO - Connected to MongoDB
# 2025-05-27 15:14:58,248 - INFO - Service started. Waiting for messages...
# 2025-05-27 15:14:58,287 - INFO - Connected to MQTT broker
# 2025-05-27 15:15:02,850 - INFO - Received message: {'evento': 'entrada', 'hora': '15:15:03', 'totalCoches': 2, 'distanciaEntrada': 5, 'distanciaSalida': 17}
# 2025-05-27 15:15:02,852 - INFO - Event stored - Type: entrada, Cars: 2
# 2025-05-27 15:15:08,898 - INFO - Received message: {'evento': 'entrada', 'hora': '15:15:09', 'totalCoches': 3, 'distanciaEntrada': 6, 'distanciaSalida': 17}
# 2025-05-27 15:15:08,900 - INFO - Event stored - Type: entrada, Cars: 3
# 2025-05-27 15:15:16,993 - INFO - Received message: {'evento': 'entrada', 'hora': '15:15:17', 'totalCoches': 4, 'distanciaEntrada': 5, 'distanciaSalida': 17}
# 2025-05-27 15:15:16,995 - INFO - Event stored - Type: entrada, Cars: 4
# 2025-05-27 15:15:24,041 - INFO - Received message: {'evento': 'entrada', 'hora': '15:15:24', 'totalCoches': 5, 'distanciaEntrada': 6, 'distanciaSalida': 17}
# 2025-05-27 15:15:24,042 - INFO - Event stored - Type: entrada, Cars: 5
# 2025-05-27 15:15:27,997 - INFO - Received message: {'evento': 'entrada', 'hora': '15:15:28', 'totalCoches': 6, 'distanciaEntrada': 6, 'distanciaSalida': 16}
# 2025-05-27 15:15:28,000 - INFO - Event stored - Type: entrada, Cars: 6
# 2025-05-27 15:15:36,064 - INFO - Received message: {'evento': 'entrada', 'hora': '15:15:36', 'totalCoches': 7, 'distanciaEntrada': 6, 'distanciaSalida': 16}
# 2025-05-27 15:15:36,066 - INFO - Event stored - Type: entrada, Cars: 7
# 2025-05-27 15:15:43,140 - INFO - Received message: {'evento': 'entrada', 'hora': '15:15:43', 'totalCoches': 8, 'distanciaEntrada': 6, 'distanciaSalida': 16}
# 2025-05-27 15:15:43,141 - INFO - Event stored - Type: entrada, Cars: 8
# 2025-05-27 15:15:51,221 - INFO - Received message: {'evento': 'entrada', 'hora': '15:15:51', 'totalCoches': 9, 'distanciaEntrada': 4, 'distanciaSalida': 16}
# 2025-05-27 15:15:51,224 - INFO - Event stored - Type: entrada, Cars: 9
# 2025-05-27 15:15:59,238 - INFO - Received message: {'evento': 'entrada', 'hora': '15:15:59', 'totalCoches': 10, 'distanciaEntrada': 6, 'distanciaSalida': 18}
# 2025-05-27 15:15:59,241 - INFO - Event stored - Type: entrada, Cars: 10
# 2025-05-27 15:16:06,347 - INFO - Received message: {'evento': 'intento_entrada_lleno', 'hora': '15:16:06', 'totalCoches': 10, 'distanciaEntrada': 5, 'distanciaSalida': 16}
# 2025-05-27 15:16:06,349 - INFO - Event stored - Type: intento_entrada_lleno, Cars: 10
# 2025-05-27 15:16:14,389 - INFO - Received message: {'evento': 'salida', 'hora': '15:16:14', 'totalCoches': 9, 'distanciaEntrada': 20, 'distanciaSalida': 4}
# 2025-05-27 15:16:14,390 - INFO - Event stored - Type: salida, Cars: 9
# 2025-05-27 15:16:23,424 - INFO - Received message: {'evento': 'entrada', 'hora': '15:16:23', 'totalCoches': 10, 'distanciaEntrada': 7, 'distanciaSalida': 16}
# 2025-05-27 15:16:23,425 - INFO - Event stored - Type: entrada, Cars: 10
# 2025-05-27 15:16:35,466 - INFO - Received message: {'evento': 'salida', 'hora': '15:16:34', 'totalCoches': 9, 'distanciaEntrada': 22, 'distanciaSalida': 4}
# 2025-05-27 15:16:35,467 - INFO - Event stored - Type: salida, Cars: 9
# 2025-05-27 15:16:42,488 - INFO - Received message: {'evento': 'entrada', 'hora': '15:16:42', 'totalCoches': 10, 'distanciaEntrada': 5, 'distanciaSalida': 18}
# 2025-05-27 15:16:42,490 - INFO - Event stored - Type: entrada, Cars: 10
# 2025-05-27 15:20:34,997 - ERROR - JSON decode error: Expecting value: line 1 column 1 (char 0)
# 2025-05-27 15:20:36,238 - INFO - Received message: {'evento': 'intento_entrada_lleno', 'hora': '15:20:36', 'totalCoches': 10, 'distanciaEntrada': 4, 'distanciaSalida': 11}
# 2025-05-27 15:20:36,240 - INFO - Event stored - Type: intento_entrada_lleno, Cars: 10
# 2025-05-27 15:20:38,192 - INFO - Received message: {'evento': 'salida', 'hora': '15:20:38', 'totalCoches': 9, 'distanciaEntrada': 20, 'distanciaSalida': 4}
# 2025-05-27 15:20:38,194 - INFO - Event stored - Type: salida, Cars: 9
# 2025-05-27 15:20:45,357 - INFO - Received message: {'evento': 'salida', 'hora': '15:20:45', 'totalCoches': 8, 'distanciaEntrada': 21, 'distanciaSalida': 2}
# 2025-05-27 15:20:45,359 - INFO - Event stored - Type: salida, Cars: 8
# 2025-05-27 15:20:56,312 - INFO - Received message: {'evento': 'salida', 'hora': '15:20:56', 'totalCoches': 7, 'distanciaEntrada': 22, 'distanciaSalida': 3}
# 2025-05-27 15:20:56,314 - INFO - Event stored - Type: salida, Cars: 7
# 2025-05-27 15:21:16,483 - INFO - Received message: {'evento': 'entrada', 'hora': '15:21:16', 'totalCoches': 8, 'distanciaEntrada': 4, 'distanciaSalida': 11}
# 2025-05-27 15:21:16,485 - INFO - Event stored - Type: entrada, Cars: 8
# 2025-05-27 15:24:00,588 - ERROR - JSON decode error: Expecting value: line 1 column 1 (char 0)
# 2025-05-27 15:24:01,816 - INFO - Received message: {'evento': 'salida', 'hora': '15:24:02', 'totalCoches': 7, 'distanciaEntrada': 21, 'distanciaSalida': 4}
# 2025-05-27 15:24:01,819 - INFO - Event stored - Type: salida, Cars: 7
# 2025-05-27 15:25:58,282 - ERROR - JSON decode error: Expecting value: line 1 column 1 (char 0)
# 2025-05-27 15:26:06,443 - INFO - Received message: {'evento': 'entrada', 'hora': '15:26:06', 'totalCoches': 1, 'distanciaEntrada': 4, 'distanciaSalida': 7}
# 2025-05-27 15:26:06,445 - INFO - Event stored - Type: entrada, Cars: 1
# 2025-05-27 15:26:10,494 - INFO - Received message: {'evento': 'salida', 'hora': '15:26:10', 'totalCoches': 0, 'distanciaEntrada': 23, 'distanciaSalida': 9}
# 2025-05-27 15:26:10,495 - INFO - Event stored - Type: salida, Cars: 0
# 2025-05-27 15:26:24,902 - INFO - Received message: {'evento': 'entrada', 'hora': '15:26:20', 'totalCoches': 1, 'distanciaEntrada': 5, 'distanciaSalida': 9}
# 2025-05-27 15:26:24,904 - INFO - Event stored - Type: entrada, Cars: 1
# 2025-05-27 15:26:24,936 - INFO - Received message: {'evento': 'salida', 'hora': '15:26:23', 'totalCoches': 0, 'distanciaEntrada': 22, 'distanciaSalida': 8}
# 2025-05-27 15:26:24,937 - INFO - Event stored - Type: salida, Cars: 0
# 2025-05-27 15:26:28,707 - INFO - Received message: {'evento': 'entrada', 'hora': '15:26:28', 'totalCoches': 1, 'distanciaEntrada': 5, 'distanciaSalida': 9}
# 2025-05-27 15:26:28,709 - INFO - Event stored - Type: entrada, Cars: 1
# 2025-05-27 15:26:31,601 - INFO - Received message: {'evento': 'salida', 'hora': '15:26:31', 'totalCoches': 0, 'distanciaEntrada': 23, 'distanciaSalida': 9}
# 2025-05-27 15:26:31,602 - INFO - Event stored - Type: salida, Cars: 0
# 2025-05-27 15:27:49,841 - ERROR - JSON decode error: Expecting value: line 1 column 1 (char 0)
# 2025-05-27 15:33:04,956 - ERROR - JSON decode error: Expecting value: line 1 column 1 (char 0)
# 2025-05-27 15:33:10,851 - INFO - Received message: {'evento': 'entrada', 'hora': '15:33:11', 'totalCoches': 1, 'distanciaEntrada': 6, 'distanciaSalida': 22}
# 2025-05-27 15:33:10,854 - INFO - Event stored - Type: entrada, Cars: 1
# 2025-05-27 15:33:23,934 - INFO - Received message: {'evento': 'salida', 'hora': '15:33:24', 'totalCoches': 0, 'distanciaEntrada': 142, 'distanciaSalida': 4}
# 2025-05-27 15:33:23,936 - INFO - Event stored - Type: salida, Cars: 0
# 2025-05-27 15:33:39,160 - INFO - Received message: {'evento': 'entrada', 'hora': '15:33:39', 'totalCoches': 1, 'distanciaEntrada': 3, 'distanciaSalida': 22}
# 2025-05-27 15:33:39,163 - INFO - Event stored - Type: entrada, Cars: 1
# 2025-05-27 15:33:47,257 - INFO - Received message: {'evento': 'entrada', 'hora': '15:33:47', 'totalCoches': 2, 'distanciaEntrada': 3, 'distanciaSalida': 22}
# 2025-05-27 15:33:47,259 - INFO - Event stored - Type: entrada, Cars: 2
# 2025-05-27 15:34:04,467 - INFO - Received message: {'evento': 'salida', 'hora': '15:34:04', 'totalCoches': 1, 'distanciaEntrada': 142, 'distanciaSalida': 2}
# 2025-05-27 15:34:04,470 - INFO - Event stored - Type: salida, Cars: 1
# 2025-05-27 15:34:18,665 - INFO - Received message: {'evento': 'entrada', 'hora': '15:34:18', 'totalCoches': 2, 'distanciaEntrada': 4, 'distanciaSalida': 22}
# 2025-05-27 15:34:18,666 - INFO - Event stored - Type: entrada, Cars: 2
# 2025-05-27 15:34:24,717 - INFO - Received message: {'evento': 'entrada', 'hora': '15:34:24', 'totalCoches': 3, 'distanciaEntrada': 9, 'distanciaSalida': 38}
# 2025-05-27 15:34:24,718 - INFO - Event stored - Type: entrada, Cars: 3
# 2025-05-27 15:34:28,787 - INFO - Received message: {'evento': 'entrada', 'hora': '15:34:29', 'totalCoches': 4, 'distanciaEntrada': 4, 'distanciaSalida': 41}
# 2025-05-27 15:34:28,789 - INFO - Event stored - Type: entrada, Cars: 4
# 2025-05-27 15:34:32,841 - INFO - Received message: {'evento': 'entrada', 'hora': '15:34:33', 'totalCoches': 5, 'distanciaEntrada': 4, 'distanciaSalida': 38}
# 2025-05-27 15:34:32,843 - INFO - Event stored - Type: entrada, Cars: 5
# 2025-05-27 15:34:40,906 - INFO - Received message: {'evento': 'entrada', 'hora': '15:34:41', 'totalCoches': 6, 'distanciaEntrada': 4, 'distanciaSalida': 37}
# 2025-05-27 15:34:40,907 - INFO - Event stored - Type: entrada, Cars: 6
# 2025-05-27 15:34:45,963 - INFO - Received message: {'evento': 'entrada', 'hora': '15:34:46', 'totalCoches': 7, 'distanciaEntrada': 5, 'distanciaSalida': 37}
# 2025-05-27 15:34:45,965 - INFO - Event stored - Type: entrada, Cars: 7
# 2025-05-27 15:34:50,108 - INFO - Received message: {'evento': 'entrada', 'hora': '15:34:50', 'totalCoches': 8, 'distanciaEntrada': 6, 'distanciaSalida': 37}
# 2025-05-27 15:34:50,110 - INFO - Event stored - Type: entrada, Cars: 8
# 2025-05-27 15:34:55,013 - INFO - Received message: {'evento': 'entrada', 'hora': '15:34:55', 'totalCoches': 9, 'distanciaEntrada': 6, 'distanciaSalida': 38}
# 2025-05-27 15:34:55,015 - INFO - Event stored - Type: entrada, Cars: 9
# 2025-05-27 15:35:01,170 - INFO - Received message: {'evento': 'entrada', 'hora': '15:35:00', 'totalCoches': 10, 'distanciaEntrada': 5, 'distanciaSalida': 37}
# 2025-05-27 15:35:01,171 - INFO - Event stored - Type: entrada, Cars: 10
# 2025-05-27 15:35:06,202 - INFO - Received message: {'evento': 'intento_entrada_lleno', 'hora': '15:35:06', 'totalCoches': 10, 'distanciaEntrada': 7, 'distanciaSalida': 39}
# 2025-05-27 15:35:06,205 - INFO - Event stored - Type: intento_entrada_lleno, Cars: 10
# 2025-05-27 15:35:20,475 - INFO - Received message: {'evento': 'salida', 'hora': '15:35:20', 'totalCoches': 9, 'distanciaEntrada': 132, 'distanciaSalida': 3}
# 2025-05-27 15:35:20,476 - INFO - Event stored - Type: salida, Cars: 9
# 2025-05-27 15:55:39,533 - WARNING - Unexpected MQTT disconnection. Reconnecting... Code: 1
# [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# 2025-05-27 15:55:52,358 - INFO - Connected to MQTT broker
